# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
from data import df_q6,df_q8,df_q9

# %%
df_employee = df_q6
df_category = df_q8
df_department = df_q9

# %%
from visualization import orders_revenue
from visualization import cat_revenue
from visualization import dep_revenue

# %%
orders_revenue(df_employee)

# %%
cat_revenue(df_category)

# %%
dep_revenue(df_department)
